# %% [markdown]
# ##Bring in libraries and dataframes and set indexes

# %%
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

#Read in data
AllData=pd.read_csv('K:\Rainshelter\Fodderbeet 2016-2017\LoggedData\RainShelterBeta_Energy.dat', #specify file path for data to read in
                         #parse_dates=True, #tell the function to parse date columns to datetime formats
                         #dayfirst=True, #tell the function that the day is before the year in the data i.e format='%d/%m/%Y %H:%M'
                         skiprows = [0,2,3], #leave out rows 1, 3 and 4 which have redundant information
                         index_col = 0, #Use the first column, which is Date, as an index
                         na_values = 'NAN')
#Bring in index data
AllDataIndex=pd.read_csv('.\IndexFiles\RadiationAndTempIndex.csv',
                         index_col = 0)

#Apply indexes to data
AllDataTransposed = AllData.transpose()
AllDataIndexed = pd.concat([AllDataIndex,AllDataTransposed], axis=1)
AllDataIndexed.index.name='ColumnHeader'
AllDataIndexed.set_index(['Measurement','Nitrogen','Irrigation','Treatment','Units','Summary','Plot','Block'], 
                         append=False, inplace=True)
Data=AllDataIndexed.transpose()
Data.index = Data.index.to_datetime()  ## for some reason the concat function changes the data type on the date indes so need to change it back
Data.sort_index(inplace=True)

Data.ix[:,22] = np.nan # wipe out errant data
#Data.ix[:,'AboveCanopyPAR'].where(Data.ix[:,'AboveCanopyPAR']<2100,other=np.nan,inplace=True)

#Calculate treatment means
DataMeans = Data.groupby(level=['Measurement','Irrigation', 'Nitrogen'],axis=1).mean()
DataMeans =  DataMeans.dropna(axis=1) #For some reason it keeps non valid combinations in so need to extract with this function

# %% [markdown]
# ## Set time slice to graph

# %%
from datetime import timedelta #Import function needed for doing date deltas 
EndDate = Data.index.max(axis=0)  #Set end of series as most recent date in file
EndDateString = EndDate.strftime("%Y-%m-%d")  #Turn this to a string
PlotDuration = .1                              #Set the duration that you want to graph for
StartDate = EndDate - timedelta(weeks=PlotDuration)       #Set start date the specified duration before the end date 
StartDateString = StartDate.strftime("%Y-%m-%d")           #Turn that into a string

# %% [markdown]
# ##Graph met data the check

# %%
DataMeans.ix[StartDateString:,['BatteryVoltage','AirTemperature','IncomingRadnKW','Leafwetness','PannelTemperature','Rainfall','RelativeHumidity','Windspeed']].plot(subplots=True, figsize=(18, 60),
                    style='r-',
                    linewidth = 2)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000000154C1C88>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000000C87B4E0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000000F615048>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000015909630>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000166E7320>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000000016731AC8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000000168427B8>], dtype=object)

# %% [markdown]
# ##Graph all sensors to check for anomolies

# %%
EnergyCheck = plt.figure(figsize = (18,80))
Variables = ['IR_SurfaceTemp','IR_SensorBodyTemp','BelowCanopyPAR','SurfaceSoilTemp']
Colors = ['r','b','g']
NRates = ['0','50','300']
IRates = ['Dry','Irrigated']
Lines = ['-','--']
Position = 1
for Variable in Variables:
    EnergyCheck.add_subplot(6,1,Position)
    ColorPosition = 0
    for NRate in NRates:
        LinePosition = 0
        for IRate in IRates:
            try:
                plt.plot(Data.ix[StartDateString:,(Variable,NRate,IRate)].index,
                    Data.ix[StartDateString:,(Variable,NRate,IRate)],
                    color = Colors[ColorPosition], 
                    linestyle = Lines[LinePosition],
                    label = NRate + ' ' + IRate, 
                    linewidth = 3)
                LinePosition +=1
            except:
                LinePosition +=1
        ColorPosition +=1
    #plt.ylim(0,.45)
    plt.ylabel('Soil Water Content (mm)', fontsize=26);
    plt.yticks(size=25)
    plt.title(Variable, fontsize=28, position = (0.5,.9))
    plt.xticks(size = 20, rotation= 30)
    if Position == 1:
        plt.legend(fontsize=20, loc=3, ncol = 3)
    Position += 1

# %%
EnergyCheck = plt.figure(figsize = (18,10))
Variables = ['IR_SurfaceTemp']
Colors = ['r','b','g']
NRates = ['0','50','300']
IRates = ['Dry','Irrigated']
Lines = ['-','--']
Position = 1
for Variable in Variables:
    ColorPosition = 0
    for NRate in NRates:
        LinePosition = 0
        for IRate in IRates:
            try:
                plt.plot(DataMeans.ix['2016-12-13',(Variable,IRate,NRate)].index,
                    DataMeans.ix['2016-12-13',(Variable,IRate,NRate)],
                    color = Colors[ColorPosition], 
                    linestyle = Lines[LinePosition],
                    label = NRate + 'kgN ' + IRate, 
                    linewidth = 3)
                LinePosition +=1
            except:
                LinePosition +=1
        ColorPosition +=1
    #plt.ylim(0,.45)
    plt.ylabel('Surface Temperature (oC)', fontsize=26);
    plt.yticks(size=25)
    plt.title('12 December 2016', fontsize=28, position = (0.8,.9))
    plt.xticks(size = 20, rotation= 30)
    #Position == 1:
    plt.legend(fontsize=20, loc=2, ncol = 1)
    Position += 1

# %%
Data.ix[:,'AboveCanopyPAR'].plot()

# %%
Data.ix[:,'BelowCanopyPAR'].plot(legend=False)

# %% [markdown]
# ##Graph treatment means

# %%
DataMeans = Data.groupby(level=['Measurement','Irrigation', 'Nitrogen'],axis=1).mean()
DataMeans = DataMeans.dropna(axis=1, how='all')
DataMeans.ix[StartDateString:,['IncomingRadnKW','ReflectedRadnKW']].plot(figsize=(18,10),style = ['y-','b--','b-','r-','r--'])
DataMeans.ix[StartDateString:,['PannelTemperature','AirTemperature','SurfaceSoilTemp']].plot(figsize=(18,10),style = ['y-','y--','b-','b-','b-','b-','b-','b-','r-','r-','r-','r-'])
DataMeans.ix[StartDateString:,['IR_SurfaceTemp','SurfaceSoilTemp']].plot(figsize=(18,10),style = ['b-','b-','b-','b-','b-','b-','r-','r-','r-','r-','r-','r-'])
DataMeans.ix[StartDateString:,['AboveCanopyPAR','BelowCanopyPAR']].plot(figsize=(18,10), style = ['y-','b--','b-','r-','r--'])

# %% [markdown]
# ##Calculate and graph radiation interception and reflection

# %%
PARint = DataMeans.ix['2015-12-10':,'BelowCanopyPAR']
FractPARint = 100 - PARint.divide(DataMeans.ix['2015-12-10':,0], axis = 0)*100
FractPARint.plot(figsize=(18,18),
                 #ylim=(0,1),
                 style = ['r-','g-','b-','r--','g--','b--'])
plt.ylim(0,100)
#RadReflect = DataMeans.ix[:,'ReflectedRadnMJ']
#RadReflect = RadReflect.divide(DataMeans.ix[:,30], axis = 0)
#RadReflect.plot(figsize=(18,10),
##                 ylim=(0,1),
 #                style = ['b--','b-','r-','r--'])
# Out:
# (0, 100)

# %%
DailySums = DataMeans.resample('D').sum()
DailyFractPARint = pd.DataFrame(index = DailySums.index,
                                columns = ['Dry 0', 'Dry 300', 'Dry 50', 'Irr 0', 'Irr 300', 'Irr 50'],
                                data = 100 - DailySums.ix[:,'BelowCanopyPAR'].values / (DailySums.ix[:,'AboveCanopyPAR'].values) * 100)
DailyFractPARint.plot(figsize=(18,18),
                 #ylim=(0,1),
                 style = ['r-','g-','b-','r--','g--','b--'])

# %%
Data.columns.tolist()
# Out:
# [('AirTemperature', 'Expt', 'Expt', 'Expt', 'Deg C', 'Avg', 'Expt', 'Expt'),
#  ('ReflectedRadn', '0', 'Irrigated', '4', 'W/m^2', 'Avg', '414', '3'),
#  ('GlobalRadn', '0', 'Irrigated', '4', 'W/m^2', 'Avg', '414', '3'),
#  ('BatteryVoltage', 'Expt', 'Expt', 'Expt', 'Volts', 'Avg', 'Expt', 'Expt'),
#  ('Leafwetness', 'Expt', 'Expt', 'Expt', 'kilohms', 'Avg', 'Expt', 'Expt'),
#  ('BelowCanopyPAR', '0', 'Dry', '1', 'mmolPAR', 'Avg', '401', '1'),
#  ('BelowCanopyPAR', '0', 'Dry', '1', 'mmolPAR', 'Avg', '410', '2'),
#  ('BelowCanopyPAR', '50', 'Dry', '2', 'mmolPAR', 'Avg', '411', '2'),
#  ('BelowCanopyPAR', '0', 'Irrigated', '4', 'mmolPAR', 'Avg', '412', '2'),
#  ('BelowCanopyPAR', '300', 'Dry', '3', 'mmolPAR', 'Avg', '413', '3'),
#  ('BelowCanopyPAR', '0', 'Irrigated', '4', 'mmolPAR', 'Avg', '414', '3'),
#  ('BelowCanopyPAR', '300', 'Irrigated', '6', 'mmolPAR', 'Avg', '415', '3'),
#  ('BelowCanopyPAR', '50', 'Dry', '2', 'mmolPAR', 'Avg', '416', '3'),
#  ('BelowCanopyPAR', '0', 'Dry', '1', 'mmolPAR', 'Avg', '417', '3'),
#  ('BelowCanopyPAR', '50', 'Irrigated', '5', 'mmolPAR', 'Avg', '418', '3'),
#  ('BelowCanopyPAR', '300', 'Dry', '3', 'mmolPAR', 'Avg', '419', '4'),
#  ('BelowCanopyPAR', '300', 'Irrigated', '6', 'mmolPAR', 'Avg', '402', '1'),
#  ('BelowCanopyPAR', '0', 'Irrigated', '4', 'mmolPAR', 'Avg', '420', '4'),
#  ('BelowCanopyPAR', '50', 'Dry', '2', 'mmolPAR', 'Avg', '421', '4'),
#  ('BelowCanopyPAR', '50', 'Irrigated', '5', 'mmolPAR', 'Avg', '422', '4'),
#  ('BelowCanopyPAR', '0', 'Dry', '1', 'mmolPAR', 'Avg', '423', '4'),
#  ('BelowCanopyPAR', '300', 'Irrigated', '6', 'mmolPAR', 'Avg', '424', '4'),
#  ('AboveCanopyPAR', 'Expt', 'Expt', 'Expt', 'mmolPAR', 'Avg', 'Expt', 'Expt'),
#  ('AboveCanopyPAR', 'Expt', 'Expt', 'Expt', 'mmolPAR', 'Avg', 'Expt', 'Expt'),
#  ('AboveCanopyPAR', 'Expt', 'Expt', 'Expt', 'mmolPAR', 'Avg', 'Expt', 'Expt'),
#  ('BelowCanopyPAR', '0', 'Irrigated', '4', 'mmolPAR', 'Avg', '403', '1'),
#  ('BelowCanopyPAR', '300', 'Dry', '3', 'mmolPAR', 'Avg', '404', '1'),
#  ('BelowCanopyPAR', '50', 'Irrigated', '5', 'mmolPAR', 'Avg', '405', '1'),
#  ('BelowCanopyPAR', '50', 'Dry', '2', 'mmolPAR', 'Avg', '406', '1'),
#  ('BelowCanopyPAR', '300', 'Irrigated', '6', 'mmolPAR', 'Avg', '407', '2'),
#  ('BelowCanopyPAR', '300', 'Dry', '3', 'mmolPAR', 'Avg', '408', '2'),
#  ('BelowCanopyPAR', '50', 'Irrigated', '5', 'mmolPAR', 'Avg', '409', '2'),
#  ('NetRadn', '0', 'Dry', '1', 'W/m^2', 'Avg', '401', '1'),
#  ('PannelTemperature', 'Expt', 'Expt', 'Expt', 'Deg C', 'Avg', 'Expt', 'Expt'),
#  ('Record', 'Expt', 'Expt', 'Expt', 'RN', 'Ref', 'Expt', 'Expt'),
#  ('RelativeHumidity', 'Expt', 'Expt', 'Expt', '%', 'Max', 'Expt', 'Expt'),
#  ('Rainfall', 'Expt', 'Expt', 'Expt', 'mm', 'Tot', 'Expt', 'Expt'),
#  ('IR_SensorBodyTemp', '0', 'Dry', '1', 'Deg C', 'Avg', '401', '1'),
#  ('IR_SensorBodyTemp', '0', 'Dry', '1', 'Deg C', 'Avg', '410', '2'),
#  ('IR_SensorBodyTemp', '50', 'Dry', '2', 'Deg C', 'Avg', '411', '2'),
#  ('IR_SensorBodyTemp', '0', 'Irrigated', '4', 'Deg C', 'Avg', '412', '2'),
#  ('IR_SensorBodyTemp', '300', 'Dry', '3', 'Deg C', 'Avg', '413', '3'),
#  ('IR_SensorBodyTemp', '0', 'Irrigated', '4', 'Deg C', 'Avg', '414', '3'),
#  ('IR_SensorBodyTemp', '300', 'Irrigated', '6', 'Deg C', 'Avg', '415', '3'),
#  ('IR_SensorBodyTemp', '50', 'Dry', '2', 'Deg C', 'Avg', '416', '3'),
#  ('IR_SensorBodyTemp', '0', 'Dry', '1', 'Deg C', 'Avg', '417', '3'),
#  ('IR_SensorBodyTemp', '50', 'Irrigated', '5', 'Deg C', 'Avg', '418', '3'),
#  ('IR_SensorBodyTemp', '300', 'Dry', '3', 'Deg C', 'Avg', '419', '4'),
#  ('IR_SensorBodyTemp', '300', 'Irrigated', '6', 'Deg C', 'Avg', '402', '1'),
#  ('IR_SensorBodyTemp', '0', 'Irrigated', '4', 'Deg C', 'Avg', '420', '4'),
#  ('IR_SensorBodyTemp', '50', 'Dry', '2', 'Deg C', 'Avg', '421', '4'),
#  ('IR_SensorBodyTemp', '50', 'Irrigated', '5', 'Deg C', 'Avg', '422', '4'),
#  ('IR_SensorBodyTemp', '0', 'Dry', '1', 'Deg C', 'Avg', '423', '4'),
#  ('IR_SensorBodyTemp', '300', 'Irrigated', '6', 'Deg C', 'Avg', '424', '4'),
#  ('IR_SensorBodyTemp', '0', 'Irrigated', '4', 'Deg C', 'Avg', '403', '1'),
#  ('IR_SensorBodyTemp', '300', 'Dry', '3', 'Deg C', 'Avg', '404', '1'),
#  ('IR_SensorBodyTemp', '50', 'Irrigated', '5', 'Deg C', 'Avg', '405', '1'),
#  ('IR_SensorBodyTemp', '50', 'Dry', '2', 'Deg C', 'Avg', '406', '1'),
#  ('IR_SensorBodyTemp', '300', 'Irrigated', '6', 'Deg C', 'Avg', '407', '2'),
#  ('IR_SensorBodyTemp', '300', 'Dry', '3', 'Deg C', 'Avg', '408', '2'),
#  ('IR_SensorBodyTemp', '50', 'Irrigated', '5', 'Deg C', 'Avg', '409', '2'),
#  ('IncomingRadnMJ', 'Expt', 'Expt', 'Expt', 'MJ/m^2', 'Tot', 'Expt', 'Expt'),
#  ('ReflectedRadnMJ', '0', 'Dry', '1', 'MJ/m^2', 'Avg', '401', '1'),
#  ('ReflectedRadnMJ', '300', 'Irrigated', '6', 'MJ/m^2', 'Avg', '415', '3'),
#  ('ReflectedRadnMJ', '50', 'Dry', '2', 'MJ/m^2', 'Avg', '416', '3'),
#  ('ReflectedRadnMJ', '0', 'Dry', '1', 'MJ/m^2', 'Avg', '417', '3'),
#  ('ReflectedRadnMJ', '300', 'Irrigated', '6', 'MJ/m^2', 'Avg', '402', '1'),
#  ('ReflectedRadnMJ', '0', 'Irrigated', '4', 'MJ/m^2', 'Avg', '403', '1'),
#  ('ReflectedRadnMJ', '50', 'Irrigated', '5', 'MJ/m^2', 'Avg', '405', '1'),
#  ('ReflectedRadnMJ', '300', 'Dry', '3', 'MJ/m^2', 'Avg', '408', '2'),
#  ('ReflectedRadnMJ', '50', 'Irrigated', '5', 'MJ/m^2', 'Avg', '409', '2'),
#  ('ReflectedRadnMJ', '0', 'Dry', '1', 'MJ/m^2', 'Avg', '410', '2'),
#  ('ReflectedRadnMJ', '50', 'Dry', '2', 'MJ/m^2', 'Avg', '411', '2'),
#  ('ReflectedRadnMJ', '300', 'Dry', '3', 'MJ/m^2', 'Avg', '413', '3'),
#  ('ReflectedRadnKW', '0', 'Dry', '1', 'kW/m^2', 'Avg', '401', '1'),
#  ('ReflectedRadnKW', '300', 'Irrigated', '6', 'kW/m^2', 'Avg', '415', '3'),
#  ('ReflectedRadnKW', '50', 'Dry', '2', 'kW/m^2', 'Avg', '416', '3'),
#  ('ReflectedRadnKW', '0', 'Dry', '1', 'kW/m^2', 'Avg', '417', '3'),
#  ('ReflectedRadnKW', '300', 'Irrigated', '6', 'kW/m^2', 'Avg', '402', '1'),
#  ('ReflectedRadnKW', '0', 'Irrigated', '4', 'kW/m^2', 'Avg', '403', '1'),
#  ('ReflectedRadnKW', '50', 'Irrigated', '5', 'kW/m^2', 'Avg', '405', '1'),
#  ('ReflectedRadnKW', '300', 'Dry', '3', 'kW/m^2', 'Avg', '408', '2'),
#  ('ReflectedRadnKW', '50', 'Irrigated', '5', 'kW/m^2', 'Avg', '409', '2'),
#  ('ReflectedRadnKW', '0', 'Dry', '1', 'kW/m^2', 'Avg', '410', '2'),
#  ('ReflectedRadnKW', '50', 'Dry', '2', 'kW/m^2', 'Avg', '411', '2'),
#  ('ReflectedRadnKW', '300', 'Dry', '3', 'kW/m^2', 'Avg', '413', '3'),
#  ('IncomingRadnKW', 'Expt', 'Expt', 'Expt', 'kW/m^2', 'Avg', 'Expt', 'Expt'),
#  ('SurfaceSoilTemp', '0', 'Dry', '1', 'Deg C', 'Avg', '401', '1'),
#  ('SurfaceSoilTemp', '0', 'Dry', '1', 'Deg C', 'Avg', '410', '2'),
#  ('SurfaceSoilTemp', '50', 'Dry', '2', 'Deg C', 'Avg', '411', '2'),
#  ('SurfaceSoilTemp', '0', 'Irrigated', '4', 'Deg C', 'Avg', '412', '2'),
#  ('SurfaceSoilTemp', '300', 'Dry', '3', 'Deg C', 'Avg', '413', '3'),
#  ('SurfaceSoilTemp', '0', 'Irrigated', '4', 'Deg C', 'Avg', '414', '3'),
#  ('SurfaceSoilTemp', '300', 'Irrigated', '6', 'Deg C', 'Avg', '415', '3'),
#  ('SurfaceSoilTemp', '50', 'Dry', '2', 'Deg C', 'Avg', '416', '3'),
#  ('SurfaceSoilTemp', '0', 'Dry', '1', 'Deg C', 'Avg', '417', '3'),
#  ('SurfaceSoilTemp', '50', 'Irrigated', '5', 'Deg C', 'Avg', '418', '3'),
#  ('SurfaceSoilTemp', '300', 'Dry', '3', 'Deg C', 'Avg', '419', '4'),
#  ('SurfaceSoilTemp', '300', 'Irrigated', '6', 'Deg C', 'Avg', '402', '1'),
#  ('SurfaceSoilTemp', '0', 'Irrigated', '4', 'Deg C', 'Avg', '420', '4'),
#  ('SurfaceSoilTemp', '50', 'Dry', '2', 'Deg C', 'Avg', '421', '4'),
#  ('SurfaceSoilTemp', '50', 'Irrigated', '5', 'Deg C', 'Avg', '422', '4'),
#  ('SurfaceSoilTemp', '0', 'Dry', '1', 'Deg C', 'Avg', '423', '4'),
#  ('SurfaceSoilTemp', '300', 'Irrigated', '6', 'Deg C', 'Avg', '424', '4'),
#  ('SurfaceSoilTemp', '0', 'Irrigated', '4', 'Deg C', 'Avg', '403', '1'),
#  ('SurfaceSoilTemp', '300', 'Dry', '3', 'Deg C', 'Avg', '404', '1'),
#  ('SurfaceSoilTemp', '50', 'Irrigated', '5', 'Deg C', 'Avg', '405', '1'),
#  ('SurfaceSoilTemp', '50', 'Dry', '2', 'Deg C', 'Avg', '406', '1'),
#  ('SurfaceSoilTemp', '300', 'Irrigated', '6', 'Deg C', 'Avg', '407', '2'),
#  ('SurfaceSoilTemp', '300', 'Dry', '3', 'Deg C', 'Avg', '408', '2'),
#  ('SurfaceSoilTemp', '50', 'Irrigated', '5', 'Deg C', 'Avg', '409', '2'),
#  ('Time', 'Expt', 'Expt', 'Expt', 'TS', 'Ref', 'Expt', 'Expt'),
#  ('IR_SurfaceTemp', '0', 'Dry', '1', 'Deg C', 'Avg', '401', '1'),
#  ('IR_SurfaceTemp', '0', 'Dry', '1', 'Deg C', 'Avg', '410', '2'),
#  ('IR_SurfaceTemp', '50', 'Dry', '2', 'Deg C', 'Avg', '411', '2'),
#  ('IR_SurfaceTemp', '0', 'Irrigated', '4', 'Deg C', 'Avg', '412', '2'),
#  ('IR_SurfaceTemp', '300', 'Dry', '3', 'Deg C', 'Avg', '413', '3'),
#  ('IR_SurfaceTemp', '0', 'Irrigated', '4', 'Deg C', 'Avg', '414', '3'),
#  ('IR_SurfaceTemp', '300', 'Irrigated', '6', 'Deg C', 'Avg', '415', '3'),
#  ('IR_SurfaceTemp', '50', 'Dry', '2', 'Deg C', 'Avg', '416', '3'),
#  ('IR_SurfaceTemp', '0', 'Dry', '1', 'Deg C', 'Avg', '417', '3'),
#  ('IR_SurfaceTemp', '50', 'Irrigated', '5', 'Deg C', 'Avg', '418', '3'),
#  ('IR_SurfaceTemp', '300', 'Dry', '3', 'Deg C', 'Avg', '419', '4'),
#  ('IR_SurfaceTemp', '300', 'Irrigated', '6', 'Deg C', 'Avg', '402', '1'),
#  ('IR_SurfaceTemp', '0', 'Irrigated', '4', 'Deg C', 'Avg', '420', '4'),
#  ('IR_SurfaceTemp', '50', 'Dry', '2', 'Deg C', 'Avg', '421', '4'),
#  ('IR_SurfaceTemp', '50', 'Irrigated', '5', 'Deg C', 'Avg', '422', '4'),
#  ('IR_SurfaceTemp', '0', 'Dry', '1', 'Deg C', 'Avg', '423', '4'),
#  ('IR_SurfaceTemp', '300', 'Irrigated', '6', 'Deg C', 'Avg', '424', '4'),
#  ('IR_SurfaceTemp', '0', 'Irrigated', '4', 'Deg C', 'Avg', '403', '1'),
#  ('IR_SurfaceTemp', '300', 'Dry', '3', 'Deg C', 'Avg', '404', '1'),
#  ('IR_SurfaceTemp', '50', 'Irrigated', '5', 'Deg C', 'Avg', '405', '1'),
#  ('IR_SurfaceTemp', '50', 'Dry', '2', 'Deg C', 'Avg', '406', '1'),
#  ('IR_SurfaceTemp', '300', 'Irrigated', '6', 'Deg C', 'Avg', '407', '2'),
#  ('IR_SurfaceTemp', '300', 'Dry', '3', 'Deg C', 'Avg', '408', '2'),
#  ('IR_SurfaceTemp', '50', 'Irrigated', '5', 'Deg C', 'Avg', '409', '2'),
#  ('IRmV', '0', 'Dry', '1', 'mV', 'Avg', '401', '1'),
#  ('IRmV', '0', 'Dry', '1', 'mV', 'Avg', '410', '2'),
#  ('IRmV', '50', 'Dry', '2', 'mV', 'Avg', '411', '2'),
#  ('IRmV', '0', 'Irrigated', '4', 'mV', 'Avg', '412', '2'),
#  ('IRmV', '300', 'Dry', '3', 'mV', 'Avg', '413', '3'),
#  ('IRmV', '0', 'Irrigated', '4', 'mV', 'Avg', '414', '3'),
#  ('IRmV', '300', 'Irrigated', '6', 'mV', 'Avg', '415', '3'),
#  ('IRmV', '50', 'Dry', '2', 'mV', 'Avg', '416', '3'),
#  ('IRmV', '0', 'Dry', '1', 'mV', 'Avg', '417', '3'),
#  ('IRmV', '50', 'Irrigated', '5', 'mV', 'Avg', '418', '3'),
#  ('IRmV', '300', 'Dry', '3', 'mV', 'Avg', '419', '4'),
#  ('IRmV', '300', 'Irrigated', '6', 'mV', 'Avg', '402', '1'),
#  ('IRmV', '0', 'Irrigated', '4', 'mV', 'Avg', '420', '4'),
#  ('IRmV', '50', 'Dry', '2', 'mV', 'Avg', '421', '4'),
#  ('IRmV', '50', 'Irrigated', '5', 'mV', 'Avg', '422', '4'),
#  ('IRmV', '0', 'Dry', '1', 'mV', 'Avg', '423', '4'),
#  ('IRmV', '300', 'Irrigated', '6', 'mV', 'Avg', '424', '4'),
#  ('IRmV', '0', 'Irrigated', '4', 'mV', 'Avg', '403', '1'),
#  ('IRmV', '300', 'Dry', '3', 'mV', 'Avg', '404', '1'),
#  ('IRmV', '50', 'Irrigated', '5', 'mV', 'Avg', '405', '1'),
#  ('IRmV', '50', 'Dry', '2', 'mV', 'Avg', '406', '1'),
#  ('IRmV', '300', 'Irrigated', '6', 'mV', 'Avg', '407', '2'),
#  ('IRmV', '300', 'Dry', '3', 'mV', 'Avg', '408', '2'),
#  ('IRmV', '50', 'Irrigated', '5', 'mV', 'Avg', '409', '2'),
#  ('Windspeed', 'Expt', 'Expt', 'Expt', 'meters/second', 'Avg', 'Expt', 'Expt')]

# %%
Data.ix[:,Data.columns.isin(['IncomingRadnKW','ReflectedRadnKW'],level=0)].plot(legend=False)

# %%
Data.ix[:,['IncomingRadnMJ','ReflectedRadiation']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-130-2b8783e70f5b> in <module>()
# ----> 1 Data.ix[:,['IncomingRadnMJ','ReflectedRadiation']]
#
# C:\Anaconda\lib\site-packages\pandas\core\indexing.pyc in __getitem__(self, key)
#      74                 pass
#      75
# ---> 76             return self._getitem_tuple(key)
#      77         else:
#      78             return self._getitem_axis(key, axis=0)
#
# C:\Anaconda\lib\site-packages\pandas\core\indexing.pyc in _getitem_tuple(self, tup)
#     778     def _getitem_tuple(self, tup):
#     779         try:
# --> 780             return self._getitem_lowerdim(tup)
#     781         except IndexingError:
#     782             pass
#
# C:\Anaconda\lib\site-packages\pandas\core\indexing.pyc in _getitem_lowerdim(self, tup)
#     885         # we may have a nested tuples indexer here
#     886         if self._is_nested_tuple_indexer(tup):
# --> 887             return self._getitem_nested_tuple(tup)
#     888
#     889         # we maybe be using a tuple to represent multiple dimensions here
#
# C:\Anaconda\lib\site-packages\pandas\core\indexing.pyc in _getitem_nested_tuple(self, tup)
#     958
#     959             current_ndim = obj.ndim
# --> 960             obj = getattr(obj, self.name)._getitem_axis(key, axis=axis)
#     961             axis += 1
#     962
#
# C:\Anaconda\lib\site-packages\pandas\core\indexing.pyc in _getitem_axis(self, key, axis)
#     994                 raise ValueError('Cannot index with multidimensional key')
#     995
# --> 996             return self._getitem_iterable(key, axis=axis)
#     997         else:
#     998
#
# C:\Anaconda\lib\site-packages\pandas\core\indexing.pyc in _getitem_iterable(self, key, axis)
#    1081
#    1082                 new_target, indexer, new_indexer = labels._reindex_non_unique(
# -> 1083                     keyarr)
#    1084
#    1085                 if new_indexer is not None:
#
# C:\Anaconda\lib\site-packages\pandas\indexes\base.pyc in _reindex_non_unique(self, target)
#    2324                 new_indexer[~check] = -1
#    2325
# -> 2326         new_index = self._shallow_copy_with_infer(new_labels, freq=None)
#    2327         return new_index, indexer, new_indexer
#    2328
#
# C:\Anaconda\lib\site-packages\pandas\indexes\multi.pyc in _shallow_copy_with_infer(self, values, **kwargs)
#     380
#     381     def _shallow_copy_with_infer(self, values=None, **kwargs):
# --> 382         return self._shallow_copy(values, **kwargs)
#     383
#     384     def _shallow_copy(self, values=None, **kwargs):
#
# C:\Anaconda\lib\site-packages\pandas\indexes\multi.pyc in _shallow_copy(self, values, **kwargs)
#     388             # discards freq
#     389             kwargs.pop('freq', None)
# --> 390             return MultiIndex.from_tuples(values, **kwargs)
#     391         return self.view()
#     392
#
# C:\Anaconda\lib\site-packages\pandas\indexes\multi.pyc in from_tuples(cls, tuples, sortorder, names)
#     881                 tuples = tuples._values
#     882
# --> 883             arrays = list(lib.tuples_to_object_array(tuples).T)
#     884         elif isinstance(tuples, list):
#     885             arrays = list(lib.to_object_array_tuples(tuples).T)
#
# pandas\src\inference.pyx in pandas.lib.tuples_to_object_array (pandas\lib.c:63780)()
#
# TypeError: Expected tuple, got str

# %%
RadIndDataOut = DailyFractPARint.transpose()
RadIndDataOut.to_excel('.\DataFrames\DailyRadnDataRSBarley.xls')

# %%
Data.to_pickle('.\DataFrames\RadnAndTempData.pkl')

# %%
Data.columns
